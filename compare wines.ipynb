# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
red_wine_original = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine_original= pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')

# %%
white_wine=white_wine_original.copy()
red_wine=red_wine_original.copy()



white_wine_to_concat=white_wine.copy()
white_wine_to_concat['color']='white'
red_wine_to_concat=red_wine.copy()
red_wine_to_concat['color']='red'

frames = [red_wine_to_concat, white_wine_to_concat]


wines = pd.concat(frames)

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# ## Visualise differences

# %%
from matplotlib.pyplot import figure

def visualise_outliers(df):
    n=0
    for item in df:
        n+=1
        plt.subplot(5, 3,n)
        res=sns.boxplot(data=df, x='color', y=item) 
    plt.tight_layout(rect=(0, 0, 6, 8)) # Ensure the plots don't overlap
    plt.show()

# %%
visualise_outliers(wines)

# %% [markdown]
# ## Anova

# %%
def anova_quality_significant(df):
    for col in df:
        if col == 'color':
            continue
        else:
         
            F, p = stats.f_oneway(df[df['color'] == 'red'][col],df[df['color'] == 'white'][col])
            if round(p,4) < 0.05: 
                print(col.upper())
                print(f'ANOVA test for mean {col} levels across wine samples with different color')
                print('F Statistic:', F, '\tp-value:', round(p,4), '\n')
                
anova_quality_significant(wines)
# Out:
# FIXED ACIDITY
# ANOVA test for mean fixed acidity levels across wine samples with different color
# F Statistic: 2016.5100580904987 	p-value: 0.0
#
# VOLATILE ACIDITY
# ANOVA test for mean volatile acidity levels across wine samples with different color
# F Statistic: 4829.317087559408 	p-value: 0.0
#
# CITRIC ACID
# ANOVA test for mean citric acid levels across wine samples with different color
# F Statistic: 236.38921401285168 	p-value: 0.0
#
# RESIDUAL SUGAR
# ANOVA test for mean residual sugar levels across wine samples with different color
# F Statistic: 899.7662891248702 	p-value: 0.0
#
# CHLORIDES
# ANOVA test for mean chlorides levels across wine samples with different color
# F Statistic: 2315.8294841354586 	p-value: 0.0
#
# FREE SULFUR DIOXIDE
# ANOVA test for mean free sulfur dioxide levels across wine samples with different color
# F Statistic: 1858.136360867368 	p-value: 0.0
#
# TOTAL SULFUR DIOXIDE
# ANOVA test for mean total sulfur dioxide levels across wine samples with different color
# F Statistic: 6252.795580210288 	p-value: 0.0
#
# DENSITY
# ANOVA test for mean density levels across wine samples with different color
# F Statistic: 1169.655246078261 	p-value: 0.0
#
# PH
# ANOVA test for mean pH levels across wine samples with different color
# F Statistic: 789.0495371666839 	p-value: 0.0
#
# SULPHATES
# ANOVA test for mean sulphates levels across wine samples with different color
# F Statistic: 2021.707535218677 	p-value: 0.0
#
# ALCOHOL
# ANOVA test for mean alcohol levels across wine samples with different color
# F Statistic: 7.067690832802164 	p-value: 0.0079
#
# QUALITY
# ANOVA test for mean quality levels across wine samples with different color
# F Statistic: 93.81180728653631 	p-value: 0.0
